# %% [markdown]
# **Loading all necessary libraries**

# %%
from langgraph.graph import START, END, StateGraph, MessagesState
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from IPython.display import Image, display
import os

print("All Libraries loaded successfully!")
# Out:
# All Libraries loaded successfully!

# %% [markdown]
# **Setting up the API Key**

# %%
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    raise ValueError("API Key is not found. Kindly set it in your .env file")

print("API key loaded successfully")
# Out:
# API key loaded successfully

# %% [markdown]
# **Initializing the LLM**

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7
)
print("LLM initialized successfully:", llm.model_name)
# Out:
# LLM initialized successfully: gpt-4o-mini

# %% [markdown]
# **Assistant Node**

# %%
# System prompt for the assistant's behavior
system_persona = SystemMessage(
    content= """You are named EaseIt acting as a customer support agent. 
    Be calm, empathetic, and solution-oriented.
    You should be able to:
    • read messages
    • act like support
    • respond politely
    Kindly format your response by avoiding the use of asterisks, hyphens and the likes"""
)

def assistant(state:MessagesState) -> dict:
    """ 
    The assistant node - processes messages and respond politely as a support.
    """
    
    # Combining system prompt with conversation history
    messages = [system_persona] + state['messages']
    
    # Getting response from LLM on messages
    response = llm.invoke(messages)
    
    # Return as state update
    return {"messages": [AIMessage(content=response.content)]}

print("Assistant node defined!")
# Out:
# Assistant node defined!

# %% [markdown]
# **Building the Graph**

# %%
# Create a StateGraph with MessagesState
builder = StateGraph(MessagesState)

# Adding the assistant node
builder.add_node("assistant", assistant)

# Define the flow:
# START → assistant → END
builder.add_edge(START, "assistant")
builder.add_edge("assistant", END)

print("Graph structure defined")
# Out:
# Graph structure defined

# %% [markdown]
# **Memory persistent for checkpointers**

# %%
memory = MemorySaver()  # Create a memory checkpointer

agent = builder.compile(checkpointer=memory)    # Compile the graph with memory

print("Agent compiled with memory")
# Out:
# Agent compiled with memory

# %% [markdown]
# **For production: It is either `SqliteSaver`(persists to SQLite database) or `MongoDBSaver`(persists to MongoDB**

# %% [markdown]
# **Visualizing the Graph**

# %%
try:
    display(Image(agent.get_graph().draw_mermaid_png()))
except Exception as e:
    print(f"Could not display graph: {e}")
    print("Graph structure: START -> assistant -> END")

# %% [markdown]
# **Running the Agent**

# %%
# Defining a session ID for the conversation
session_id = "chat-01"

def run_conversation(user_input: str, thread_id: str = session_id):
    
    result = agent.invoke(
        {"messages": [HumanMessage(content=user_input)]}, 
        config={"configurable": {"thread_id": thread_id}}
    )
    
    # Print the conversation
    for message in result["messages"]:
        if isinstance(message, HumanMessage):
            print(f"\nUser: {message.content}")
        elif isinstance(message, AIMessage):
            print(f"\nAgent: {message.content}")
            
    print("\n" + "~"*70)
    
print("Conversation function is ready!")
# Out:
# Conversation function is ready!

# %%
run_conversation("Hello! What's your name?")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("What's my favorite colour?")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
# First message
run_conversation("My favorite color is blue")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# User: My favorite color is blue
#
# Agent: That’s a lovely choice! Blue is often associated with calmness and serenity. If there’s anything specific you’d like to talk about related to your favorite color or anything else, just let me know!
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("What's my favorite colour?")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# User: My favorite color is blue
#
# Agent: That’s a lovely choice! Blue is often associated with calmness and serenity. If there’s anything specific you’d like to talk about related to your favorite color or anything else, just let me know!
#
# User: What's my favorite colour?
#
# Agent: Your favorite color is blue. If there’s anything else you would like to share or any questions you have, feel free to ask!
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("I bought a laptop last week")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# User: My favorite color is blue
#
# Agent: That’s a lovely choice! Blue is often associated with calmness and serenity. If there’s anything specific you’d like to talk about related to your favorite color or anything else, just let me know!
#
# User: What's my favorite colour?
#
# Agent: Your favorite color is blue. If there’s anything else you would like to share or any questions you have, feel free to ask!
#
# User: I bought a laptop last week
#
# Agent: That’s great to hear! How is your new laptop working for you so far? If you have any questions or need assistance with it, feel free to let me know.
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("It won't turn on")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# User: My favorite color is blue
#
# Agent: That’s a lovely choice! Blue is often associated with calmness and serenity. If there’s anything specific you’d like to talk about related to your favorite color or anything else, just let me know!
#
# User: What's my favorite colour?
#
# Agent: Your favorite color is blue. If there’s anything else you would like to share or any questions you have, feel free to ask!
#
# User: I bought a laptop last week
#
# Agent: That’s great to hear! How is your new laptop working for you so far? If you have any questions or need assistance with it, feel free to let me know.
#
# User: It won't turn on
#
# Agent: I’m sorry to hear that your laptop won’t turn on. Let’s try to troubleshoot the issue together.
#
# First, please check the following:
# - Is the laptop plugged in and is the power adapter connected properly?
# - If it’s a removable battery, have you tried removing and reinserting it?
# - Can you see any lights on the laptop when you press the power button?
#
# Let me know what you find, and we can go from there.
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("It won't turn on", thread_id="101")
# Out:
# User: It won't turn on
#
# Agent: I'm sorry to hear that your device is not turning on. I understand how frustrating that can be. Let's try a few steps to see if we can get it working.
#
# First, please ensure that the device is charged. If it has a removable battery, you might want to take it out for a moment and then put it back in. If it doesn't, try holding down the power button for about 10 to 15 seconds to see if it responds.
#
# If it still doesn't turn on, please let me know what kind of device you are using, and I can provide more specific troubleshooting steps.
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("I am using Samsung", thread_id="101")
# Out:
# User: It won't turn on
#
# Agent: I'm sorry to hear that your device is not turning on. I understand how frustrating that can be. Let's try a few steps to see if we can get it working.
#
# First, please ensure that the device is charged. If it has a removable battery, you might want to take it out for a moment and then put it back in. If it doesn't, try holding down the power button for about 10 to 15 seconds to see if it responds.
#
# If it still doesn't turn on, please let me know what kind of device you are using, and I can provide more specific troubleshooting steps.
#
# User: I am using Samsung
#
# Agent: Thank you for the information. Here are some steps you can try for your Samsung device:
#
# 1. **Charge the Device**: Make sure you are using a working charger and cable. Connect your device to the charger for at least 15 minutes and then try turning it on again.
#
# 2. **Force Restart**: Press and hold the power button and the volume down button simultaneously for about 10 to 15 seconds. This should force your device to restart.
#
# 3. **Check for Damage**: Inspect the charging port and cable for any visible damage or debris that might be preventing it from charging properly.
#
# If none of these steps work, it may be a hardware issue. In that case, I recommend contacting Samsung support or visiting a service center for further assistance. Please let me know if you need any more help!
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
run_conversation("It won't turn on still")
# Out:
# User: Hello! What's your name?
#
# Agent: Hello! I don’t have a personal name, but you can call me your customer support assistant. How can I help you today?
#
# User: Hello! What's your name?
#
# Agent: Hello again! I'm here as your customer support assistant. How can I assist you today?
#
# User: Hello! What's your name?
#
# Agent: Hello! I’m your customer support assistant. How can I help you today?
#
# User: What's my favorite colour?
#
# Agent: I’m not sure what your favorite color is, but I would love to hear about it! If there’s anything else you’d like to discuss or any questions you have, feel free to let me know.
#
# User: My favorite color is blue
#
# Agent: That’s a lovely choice! Blue is often associated with calmness and serenity. If there’s anything specific you’d like to talk about related to your favorite color or anything else, just let me know!
#
# User: What's my favorite colour?
#
# Agent: Your favorite color is blue. If there’s anything else you would like to share or any questions you have, feel free to ask!
#
# User: I bought a laptop last week
#
# Agent: That’s great to hear! How is your new laptop working for you so far? If you have any questions or need assistance with it, feel free to let me know.
#
# User: It won't turn on
#
# Agent: I’m sorry to hear that your laptop won’t turn on. Let’s try to troubleshoot the issue together.
#
# First, please check the following:
# - Is the laptop plugged in and is the power adapter connected properly?
# - If it’s a removable battery, have you tried removing and reinserting it?
# - Can you see any lights on the laptop when you press the power button?
#
# Let me know what you find, and we can go from there.
#
# User: It won't turn on still
#
# Agent: I understand how frustrating that can be. Let’s try a few more steps to see if we can get it working.
#
# Please try the following:
# - Disconnect the power adapter and remove the battery (if it’s removable). Press and hold the power button for about 15 seconds to discharge any residual power.
# - After that, reconnect the battery and power adapter, then try turning it on again.
#
# If it still doesn’t turn on, it might be best to contact the manufacturer’s support or take it to a technician for further assistance. Let me know how it goes or if you need more help!
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
